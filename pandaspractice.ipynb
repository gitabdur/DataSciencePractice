# %% [markdown]
# ### Importing Pandas Library

# %%
import pandas as pd

# %% [markdown]
# ### Reading the Given CSV file

# %%
df = pd.read_csv('data/survey_results_public.csv')

# %% [markdown]
# ### Printing the entire dataframe but this displays only 20 columns randomly chosen

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %% [markdown]
# ### Finding the no of rows and columns in the dataframe

# %%
df.shape
# Out:
# (88883, 85)

# %% [markdown]
# ### All the column names along with their datatypes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88883 entries, 0 to 88882
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              88883 non-null  int64
#  1   MainBranch              88331 non-null  object
#  2   Hobbyist                88883 non-null  object
#  3   OpenSourcer             88883 non-null  object
#  4   OpenSource              86842 non-null  object
#  5   Employment              87181 non-null  object
#  6   Country                 88751 non-null  object
#  7   Student                 87014 non-null  object
#  8   EdLevel                 86390 non-null  object
#  9   UndergradMajor          75614 non-null  object
#  10  EduOther                84260 non-null  object
#  11  OrgSize                 71791 non-null  object
#  12  DevType                 81335 non-null  object
#  13  YearsCode               87938 non-null  object
# ...

# %% [markdown]
# ### To access all the columns of the dataframe

# %%
pd.set_option('display.max_columns',85)

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %% [markdown]
# ### Getting the other dataframe

# %%
schema_df = pd.read_csv('data/survey_results_schema.csv')

# %%
schema_df
# Out:
#           Column                                       QuestionText
# 0     Respondent  Randomized respondent ID number (not in order ...
# 1     MainBranch  Which of the following options best describes ...
# 2       Hobbyist                            Do you code as a hobby?
# 3    OpenSourcer        How often do you contribute to open source?
# 4     OpenSource  How do you feel about the quality of open sour...
# ..           ...                                                ...
# 80     Sexuality  Which of the following do you currently identi...
# 81     Ethnicity  Which of the following do you identify as? Ple...
# 82    Dependents  Do you have any dependents (e.g., children, el...
# 83  SurveyLength  How do you feel about the length of the survey...
# 84    SurveyEase  How easy or difficult was this survey to compl...
#
# [85 rows x 2 columns]

# %%
pd.set_option('display.max_rows',85)

# %%
schema_df
# Out:
#                     Column                                       QuestionText
# 0               Respondent  Randomized respondent ID number (not in order ...
# 1               MainBranch  Which of the following options best describes ...
# 2                 Hobbyist                            Do you code as a hobby?
# 3              OpenSourcer        How often do you contribute to open source?
# 4               OpenSource  How do you feel about the quality of open sour...
# 5               Employment  Which of the following best describes your cur...
# 6                  Country          In which country do you currently reside?
# 7                  Student  Are you currently enrolled in a formal, degree...
# 8                  EdLevel  Which of the following best describes the high...
# 9           UndergradMajor  What was your main or most important field of ...
# 10                EduOther  Which of the following types of non-degree edu...
# ...

# %% [markdown]
# ### To get the first n rows from dataframe , default value is 5

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %% [markdown]
# ### Printing a specific column of the dataframe (Method 1)

# %%
df.Employment
# Out:
# 0                   Not employed, and not looking for work
# 1                       Not employed, but looking for work
# 2                                       Employed full-time
# 3                                       Employed full-time
# 4                                       Employed full-time
#                                ...
# 88878               Not employed, and not looking for work
# 88879                                                  NaN
# 88880                                   Employed full-time
# 88881    Independent contractor, freelancer, or self-em...
# 88882               Not employed, and not looking for work
# Name: Employment, Length: 88883, dtype: object

# %% [markdown]
# ### Printing a specific column of the dataframe (Method 2)

# %%
df['Employment']
# Out:
# 0                   Not employed, and not looking for work
# 1                       Not employed, but looking for work
# 2                                       Employed full-time
# 3                                       Employed full-time
# 4                                       Employed full-time
#                                ...
# 88878               Not employed, and not looking for work
# 88879                                                  NaN
# 88880                                   Employed full-time
# 88881    Independent contractor, freelancer, or self-em...
# 88882               Not employed, and not looking for work
# Name: Employment, Length: 88883, dtype: object

# %% [markdown]
# ### Printing Multiple columns

# %%
df[['MainBranch','Employment']]
# Out:
#                                               MainBranch  \
# 0                 I am a student who is learning to code
# 1                 I am a student who is learning to code
# 2      I am not primarily a developer, but I write co...
# 3                         I am a developer by profession
# 4                         I am a developer by profession
# ...                                                  ...
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                                                NaN
#
#                                               Employment
# 0                 Not employed, and not looking for work
# 1                     Not employed, but looking for work
# 2                                     Employed full-time
# ...

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %% [markdown]
# ### iloc prints all the columns and their value belonging to a partcular row ( using index )

# %%
df.iloc[3]
# Out:
# Respondent                                                                4
# MainBranch                                   I am a developer by profession
# Hobbyist                                                                 No
# OpenSourcer                                                           Never
# OpenSource                The quality of OSS and closed source software ...
# Employment                                               Employed full-time
# Country                                                       United States
# Student                                                                  No
# EdLevel                            Bachelor’s degree (BA, BS, B.Eng., etc.)
# UndergradMajor            Computer science, computer engineering, or sof...
# EduOther                  Taken an online course in programming or softw...
# OrgSize                                                100 to 499 employees
# ...

# %% [markdown]
# ### To print the rows with values mentioned within the brackets ( using index for both row and column)

# %%
df.iloc[[0,1]]
# Out:
#    Respondent                              MainBranch Hobbyist  \
# 0           1  I am a student who is learning to code      Yes
# 1           2  I am a student who is learning to code       No
#
#                OpenSourcer                                         OpenSource  \
# 0                    Never  The quality of OSS and closed source software ...
# 1  Less than once per year  The quality of OSS and closed source software ...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
#
#           Student                                            EdLevel  \
# 0              No                          Primary/elementary school
# 1  Yes, full-time  Secondary school (e.g. American high school, G...
#
#   UndergradMajor                                           EduOther OrgSize  \
# ...

# %% [markdown]
# ### To print the rows within the given range [a,b)

# %%
df.iloc[0:3]
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
#
#                OpenSourcer                                         OpenSource  \
# 0                    Never  The quality of OSS and closed source software ...
# 1  Less than once per year  The quality of OSS and closed source software ...
# 2                    Never  The quality of OSS and closed source software ...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
# 2                      Employed full-time                Thailand
#
#           Student                                            EdLevel  \
# ...

# %% [markdown]
# ### To print the rows with specific column values mentioned within the brackets

# %%
df.iloc[[0,1],2]
# Out:
# 0    Yes
# 1     No
# Name: Hobbyist, dtype: object

# %% [markdown]
# ### using loc we need to write the column name and not index to get its value

# %%
df.loc[0]
# Out:
# Respondent                                                                1
# MainBranch                           I am a student who is learning to code
# Hobbyist                                                                Yes
# OpenSourcer                                                           Never
# OpenSource                The quality of OSS and closed source software ...
# Employment                           Not employed, and not looking for work
# Country                                                      United Kingdom
# Student                                                                  No
# EdLevel                                           Primary/elementary school
# UndergradMajor                                                          NaN
# EduOther                  Taught yourself a new language, framework, or ...
# OrgSize                                                                 NaN
# ...

# %%
df.loc[[0,1]]
# Out:
#    Respondent                              MainBranch Hobbyist  \
# 0           1  I am a student who is learning to code      Yes
# 1           2  I am a student who is learning to code       No
#
#                OpenSourcer                                         OpenSource  \
# 0                    Never  The quality of OSS and closed source software ...
# 1  Less than once per year  The quality of OSS and closed source software ...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
#
#           Student                                            EdLevel  \
# 0              No                          Primary/elementary school
# 1  Yes, full-time  Secondary school (e.g. American high school, G...
#
#   UndergradMajor                                           EduOther OrgSize  \
# ...

# %%
df.loc[[0,1],['Hobbyist']]
# Out:
#   Hobbyist
# 0      Yes
# 1       No

# %%
df.loc[[0,1],['Hobbyist','Country']]
# Out:
#   Hobbyist                 Country
# 0      Yes          United Kingdom
# 1       No  Bosnia and Herzegovina

# %%
df.loc[[0,1],['Country','Hobbyist']]
# Out:
#                   Country Hobbyist
# 0          United Kingdom      Yes
# 1  Bosnia and Herzegovina       No

# %%
df.loc[0:3,['Country','Hobbyist']]
# Out:
#                   Country Hobbyist
# 0          United Kingdom      Yes
# 1  Bosnia and Herzegovina       No
# 2                Thailand      Yes
# 3           United States       No

# %% [markdown]
# ### Changing the index from default 0,1,2,3.... to 'Respondent' column

# %%
df = pd.read_csv('data/survey_results_public.csv',index_col='Respondent')

# %%
df
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
df.loc[1]
# Out:
# MainBranch                           I am a student who is learning to code
# Hobbyist                                                                Yes
# OpenSourcer                                                           Never
# OpenSource                The quality of OSS and closed source software ...
# Employment                           Not employed, and not looking for work
# Country                                                      United Kingdom
# Student                                                                  No
# EdLevel                                           Primary/elementary school
# UndergradMajor                                                          NaN
# EduOther                  Taught yourself a new language, framework, or ...
# OrgSize                                                                 NaN
# DevType                                                                 NaN
# ...

# %% [markdown]
# ### Changing the index from default 0,1,2,3.... to 'Column' column

# %%
schema_df
# Out:
#                     Column                                       QuestionText
# 0               Respondent  Randomized respondent ID number (not in order ...
# 1               MainBranch  Which of the following options best describes ...
# 2                 Hobbyist                            Do you code as a hobby?
# 3              OpenSourcer        How often do you contribute to open source?
# 4               OpenSource  How do you feel about the quality of open sour...
# 5               Employment  Which of the following best describes your cur...
# 6                  Country          In which country do you currently reside?
# 7                  Student  Are you currently enrolled in a formal, degree...
# 8                  EdLevel  Which of the following best describes the high...
# 9           UndergradMajor  What was your main or most important field of ...
# 10                EduOther  Which of the following types of non-degree edu...
# ...

# %%
schema_df = pd.read_csv('data/survey_results_schema.csv',index_col='Column')

# %%
schema_df
# Out:
#                                                              QuestionText
# Column
# Respondent              Randomized respondent ID number (not in order ...
# MainBranch              Which of the following options best describes ...
# Hobbyist                                          Do you code as a hobby?
# OpenSourcer                   How often do you contribute to open source?
# OpenSource              How do you feel about the quality of open sour...
# Employment              Which of the following best describes your cur...
# Country                         In which country do you currently reside?
# Student                 Are you currently enrolled in a formal, degree...
# EdLevel                 Which of the following best describes the high...
# UndergradMajor          What was your main or most important field of ...
# EduOther                Which of the following types of non-degree edu...
# OrgSize                 Approximately how many people are employed by ...
# ...

# %%
schema_df.loc['MainBranch']
# Out:
# QuestionText    Which of the following options best describes ...
# Name: MainBranch, dtype: object

# %%
schema_df.loc['MainBranch','QuestionText']
# Out:
# 'Which of the following options best describes you today? Here, by "developer" we mean "someone who writes code."'

# %% [markdown]
# ### Sorting the index in alphabetical order(ascending)

# %%
schema_df.sort_index()
# Out:
#                                                              QuestionText
# Column
# Age                     What is your age (in years)? If you prefer not...
# Age1stCode              At what age did you write your first line of c...
# BetterLife              Do you think people born today will have a bet...
# BlockchainIs            Blockchain / cryptocurrency technology is prim...
# BlockchainOrg           How is your organization thinking about or imp...
# CareerSat               Overall, how satisfied are you with your caree...
# CodeRev                          Do you review code as part of your work?
# CodeRevHrs              On average, how many hours per week do you spe...
# CompFreq                 Is that compensation weekly, monthly, or yearly?
# CompTotal               What is your current total compensation (salar...
# Containers              How do you use containers (Docker, Open Contai...
# ConvertedComp           Salary converted to annual USD salaries using ...
# ...

# %% [markdown]
# ### Sorting the index in alphabetical order(ascending)

# %%
schema_df.sort_index(ascending=False)
# Out:
#                                                              QuestionText
# Column
# YearsCodePro            How many years have you coded professionally (...
# YearsCode               Including any education, how many years have y...
# WorkWeekHrs              On average, how many hours per week do you work?
# WorkRemote                                How often do you work remotely?
# WorkPlan                          How structured or planned is your work?
# WorkLoc                                   Where would you prefer to work?
# WorkChallenge           Of these options, what are your greatest chall...
# WelcomeChange           Compared to last year, how welcome do you feel...
# WebFrameWorkedWith      Which of the following web frameworks have you...
# WebFrameDesireNextYear  Which of the following web frameworks have you...
# UnitTests               Does your company regularly employ unit tests ...
# UndergradMajor          What was your main or most important field of ...
# ...

# %% [markdown]
# ### Using conditions to get desired results

# %%
high_salary= (df['ConvertedComp'] > 70000)

# %%
df.loc[high_salary,['Country','LanguageWorkedWith','ConvertedComp']]
# Out:
#                    Country                                 LanguageWorkedWith  \
# Respondent
# 6                   Canada                                         Java;R;SQL
# 9              New Zealand  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 13           United States  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 16          United Kingdom  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...
# 22           United States  Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# ...                    ...                                                ...
# 88876        United States  Bash/Shell/PowerShell;C#;HTML/CSS;Java;Python;...
# 88877        United States  Bash/Shell/PowerShell;C;Clojure;HTML/CSS;Java;...
# 88878        United States               HTML/CSS;JavaScript;Scala;TypeScript
# 88879              Finland                   Bash/Shell/PowerShell;C++;Python
# 88882          Netherlands             C#;HTML/CSS;Java;JavaScript;PHP;Python
#
# ...

# %%
countries = {'United States','India','Canada', 'United Kingdom', 'Germany'}
filt1=df['Country'].isin(countries)

# %%
df.loc[filt1, 'Country']
# Out:
# Respondent
# 1        United Kingdom
# 4         United States
# 6                Canada
# 8                 India
# 10                India
#               ...
# 85642     United States
# 85961    United Kingdom
# 86012             India
# 88282     United States
# 88377            Canada
# Name: Country, Length: 45008, dtype: object

# %%
df['LanguageWorkedWith']
# Out:
# Respondent
# 1                          HTML/CSS;Java;JavaScript;Python
# 2                                      C++;HTML/CSS;Python
# 3                                                 HTML/CSS
# 4                                      C;C++;C#;Python;SQL
# 5              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
#                                ...
# 88377                        HTML/CSS;JavaScript;Other(s):
# 88601                                                  NaN
# 88802                                                  NaN
# 88816                                                  NaN
# 88863    Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# Name: LanguageWorkedWith, Length: 88883, dtype: object

# %%
filt2 = df['LanguageWorkedWith'].str.contains('Python',na = False)

# %%
filt2
# Out:
# Respondent
# 1         True
# 2         True
# 3        False
# 4         True
# 5         True
#          ...
# 88377    False
# 88601    False
# 88802    False
# 88816    False
# 88863    False
# Name: LanguageWorkedWith, Length: 88883, dtype: bool

# %%
df.loc[filt2,'LanguageWorkedWith']
# Out:
# Respondent
# 1                          HTML/CSS;Java;JavaScript;Python
# 2                                      C++;HTML/CSS;Python
# 4                                      C;C++;C#;Python;SQL
# 5              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 8        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
#                                ...
# 84539    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 85738      Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 86566      Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 87739             C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88212                           HTML/CSS;JavaScript;Python
# Name: LanguageWorkedWith, Length: 36443, dtype: object

# %% [markdown]
# ### Renaming a column of the dataframe and using inplace to make the change permanent

# %%
df.rename(columns={'ConvertedComp':'Salary(USD)'},inplace ='True')

# %%
df['Salary(USD)']
# Out:
# Respondent
# 1            NaN
# 2            NaN
# 3         8820.0
# 4        61000.0
# 5            NaN
#           ...
# 88377        NaN
# 88601        NaN
# 88802        NaN
# 88816        NaN
# 88863        NaN
# Name: Salary(USD), Length: 88883, dtype: float64

# %% [markdown]
# ### Changing the values of Hobbyist from YES and NO to TRUE and FALSE

# %%
df['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4         No
# 5        Yes
#         ...
# 88377    Yes
# 88601     No
# 88802     No
# 88816     No
# 88863    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df['Hobbyist'].map({'Yes': True,'No': False})
# Out:
# Respondent
# 1         True
# 2        False
# 3         True
# 4        False
# 5         True
#          ...
# 88377     True
# 88601    False
# 88802    False
# 88816    False
# 88863     True
# Name: Hobbyist, Length: 88883, dtype: bool

# %% [markdown]
# ### Using MAP function to make teh cabove cahnges directly into the dataframe

# %%
df['Hobbyist'] = df['Hobbyist'].map({'Yes': True,'No': False})

# %%
df
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      True
# 2                      I am a student who is learning to code     False
# 3           I am not primarily a developer, but I write co...      True
# 4                              I am a developer by profession     False
# 5                              I am a developer by profession      True
# ...                                                       ...       ...
# 88377                                                     NaN      True
# 88601                                                     NaN     False
# 88802                                                     NaN     False
# 88816                                                     NaN     False
# 88863                                                     NaN      True
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %% [markdown]
# ### Deleting Two cloumns from a dataframe

# %%
df.drop(columns=['Age1stCode','YearsCodePro'])
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      True
# 2                      I am a student who is learning to code     False
# 3           I am not primarily a developer, but I write co...      True
# 4                              I am a developer by profession     False
# 5                              I am a developer by profession      True
# ...                                                       ...       ...
# 88377                                                     NaN      True
# 88601                                                     NaN     False
# 88802                                                     NaN     False
# 88816                                                     NaN     False
# 88863                                                     NaN      True
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
df
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      True
# 2                      I am a student who is learning to code     False
# 3           I am not primarily a developer, but I write co...      True
# 4                              I am a developer by profession     False
# 5                              I am a developer by profession      True
# ...                                                       ...       ...
# 88377                                                     NaN      True
# 88601                                                     NaN     False
# 88802                                                     NaN     False
# 88816                                                     NaN     False
# 88863                                                     NaN      True
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %% [markdown]
# ### Making the deletion permanent

# %%
df.drop(columns=['Age1stCode','YearsCodePro'],inplace=True)

# %%
df
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      True
# 2                      I am a student who is learning to code     False
# 3           I am not primarily a developer, but I write co...      True
# 4                              I am a developer by profession     False
# 5                              I am a developer by profession      True
# ...                                                       ...       ...
# 88377                                                     NaN      True
# 88601                                                     NaN     False
# 88802                                                     NaN     False
# 88816                                                     NaN     False
# 88863                                                     NaN      True
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %% [markdown]
# ### Dropping a a specific row of data using index

# %%
df.drop(index=2)
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      True
# 3           I am not primarily a developer, but I write co...      True
# 4                              I am a developer by profession     False
# 5                              I am a developer by profession      True
# 6           I am not primarily a developer, but I write co...      True
# ...                                                       ...       ...
# 88377                                                     NaN      True
# 88601                                                     NaN     False
# 88802                                                     NaN     False
# 88816                                                     NaN     False
# 88863                                                     NaN      True
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %% [markdown]
# ### Sorting on the basis of Countries in ascending order

# %%
df.sort_values(by= 'Country')
# Out:
#                                 MainBranch  Hobbyist              OpenSourcer  \
# Respondent
# 39258       I am a developer by profession      True  Less than once per year
# 63129       I am a developer by profession      True                    Never
# 85715       I am a developer by profession     False  Less than once per year
# 50767       I am a developer by profession     False  Less than once per year
# 2782                                   NaN      True  Less than once per year
# ...                                    ...       ...                      ...
# 88062                                  NaN     False                    Never
# 88076                                  NaN     False                    Never
# 88601                                  NaN     False                    Never
# 88802                                  NaN     False                    Never
# 88816                                  NaN     False                    Never
#
# ...

# %% [markdown]
# ### Sorting on the basis of Countries in ascending order

# %%
df.sort_values(by= 'Country',ascending = False)
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 69495       I used to be a developer by profession, but no...     False
# 51356                  I am a student who is learning to code     False
# 6486                   I am a student who is learning to code      True
# 1886                           I am a developer by profession      True
# 55405                          I am a developer by profession      True
# ...                                                       ...       ...
# 88062                                                     NaN     False
# 88076                                                     NaN     False
# 88601                                                     NaN     False
# 88802                                                     NaN     False
# 88816                                                     NaN     False
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %% [markdown]
# ### Sorting on the basis of 2 or more criteria

# %%
df.sort_values(by =['Country', 'Respondent'])
# Out:
#                                         MainBranch  Hobbyist  \
# Respondent
# 722                 I am a developer by profession     False
# 2782                                           NaN      True
# 6417        I am a student who is learning to code      True
# 7085                I am a developer by profession      True
# 7353                I am a developer by profession     False
# ...                                            ...       ...
# 88062                                          NaN     False
# 88076                                          NaN     False
# 88601                                          NaN     False
# 88802                                          NaN     False
# 88816                                          NaN     False
#
#                                                   OpenSourcer  \
# Respondent
# 722         Less than once a month but more than once per ...
# 2782                                  Less than once per year
# ...

# %% [markdown]
# ### Sorting on the basis of 2 or more criteria specifying conditions for each columns

# %%
df.sort_values(by = ['Country', 'Respondent'], ascending = [True,False])
# Out:
#                                 MainBranch  Hobbyist  \
# Respondent
# 88731          I code primarily as a hobby      True
# 88582       I am a developer by profession      True
# 87091       I am a developer by profession      True
# 86932       I am a developer by profession      True
# 86362       I am a developer by profession      True
# ...                                    ...       ...
# 6575                                   NaN     False
# 5688                                   NaN     False
# 4587                                   NaN     False
# 4271                                   NaN     False
# 2679                                   NaN     False
#
#                                                   OpenSourcer  \
# Respondent
# 88731       Less than once a month but more than once per ...
# 88582                                 Less than once per year
# 87091       Less than once a month but more than once per ...
# ...

# %%
df
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      True
# 2                      I am a student who is learning to code     False
# 3           I am not primarily a developer, but I write co...      True
# 4                              I am a developer by profession     False
# 5                              I am a developer by profession      True
# ...                                                       ...       ...
# 88377                                                     NaN      True
# 88601                                                     NaN     False
# 88802                                                     NaN     False
# 88816                                                     NaN     False
# 88863                                                     NaN      True
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
df.sort_values(by = 'Country',inplace=True)

# %%
df[['Country','Salary(USD)']].head(50)
# Out:
#                 Country  Salary(USD)
# Respondent
# 39258       Afghanistan      19152.0
# 63129       Afghanistan    1000000.0
# 85715       Afghanistan          NaN
# 50767       Afghanistan          NaN
# 2782        Afghanistan          NaN
# 63019       Afghanistan          NaN
# 6417        Afghanistan          NaN
# 40000       Afghanistan          NaN
# 88731       Afghanistan          NaN
# 48436       Afghanistan       4464.0
# 10746       Afghanistan       3996.0
# 62525       Afghanistan          NaN
# 49702       Afghanistan          NaN
# 33178       Afghanistan          NaN
# 60946       Afghanistan          NaN
# 86362       Afghanistan          NaN
# 88582       Afghanistan          NaN
# 28638       Afghanistan          0.0
# 722         Afghanistan          0.0
# 26340       Afghanistan          NaN
# 86932       Afghanistan          NaN
# 85825       Afghanistan          NaN
# 7085        Afghanistan      14364.0
# 7353        Afghanistan          NaN
# ...

# %%
df.sort_values(by = ['Country','Salary(USD)'],ascending=[True,False],inplace=True)

# %%
df[['Country','Salary(USD)']].head(50)
# Out:
#                 Country  Salary(USD)
# Respondent
# 63129       Afghanistan    1000000.0
# 50499       Afghanistan     153216.0
# 39258       Afghanistan      19152.0
# 58450       Afghanistan      17556.0
# 7085        Afghanistan      14364.0
# 22450       Afghanistan       7980.0
# 48436       Afghanistan       4464.0
# 10746       Afghanistan       3996.0
# 8149        Afghanistan       1596.0
# 29736       Afghanistan       1116.0
# 28638       Afghanistan          0.0
# 722         Afghanistan          0.0
# 85715       Afghanistan          NaN
# 50767       Afghanistan          NaN
# 2782        Afghanistan          NaN
# 63019       Afghanistan          NaN
# 6417        Afghanistan          NaN
# 40000       Afghanistan          NaN
# 88731       Afghanistan          NaN
# 62525       Afghanistan          NaN
# 49702       Afghanistan          NaN
# 33178       Afghanistan          NaN
# 60946       Afghanistan          NaN
# 86362       Afghanistan          NaN
# ...

# %%
df
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 63129                          I am a developer by profession      True
# 50499       I am not primarily a developer, but I write co...      True
# 39258                          I am a developer by profession      True
# 58450                          I am a developer by profession      True
# 7085                           I am a developer by profession      True
# ...                                                       ...       ...
# 88062                                                     NaN     False
# 88076                                                     NaN     False
# 88601                                                     NaN     False
# 88802                                                     NaN     False
# 88816                                                     NaN     False
#
#                         OpenSourcer  \
# Respondent
# 63129                         Never
# ...

# %%
df['Salary(USD)'].nlargest(10)
# Out:
# Respondent
# 25983    2000000.0
# 87896    2000000.0
# 22013    2000000.0
# 28243    2000000.0
# 72732    2000000.0
# 78151    2000000.0
# 80200    2000000.0
# 52132    2000000.0
# 75561    2000000.0
# 32250    2000000.0
# Name: Salary(USD), dtype: float64

# %%
df.nlargest(10,'Salary(USD)')
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 25983                          I am a developer by profession      True
# 87896                          I am a developer by profession      True
# 22013                          I am a developer by profession      True
# 28243                          I am a developer by profession      True
# 72732       I am not primarily a developer, but I write co...     False
# 78151                          I am a developer by profession      True
# 80200                          I am a developer by profession      True
# 52132                          I am a developer by profession      True
# 75561                          I am a developer by profession      True
# 32250                          I am a developer by profession      True
#
#                                                   OpenSourcer  \
# Respondent
# 25983                                 Less than once per year
# ...

# %% [markdown]
# ### Displaying lowest 10 values using a function

# %%
df['Salary(USD)'].nsmallest(10)
# Out:
# Respondent
# 28638    0.0
# 722      0.0
# 13825    0.0
# 40913    0.0
# 30630    0.0
# 69049    0.0
# 19340    0.0
# 16214    0.0
# 29355    0.0
# 1685     0.0
# Name: Salary(USD), dtype: float64

# %% [markdown]
# ### Displaying the dataframe lowest 10 values using a function

# %%
df.nsmallest(10,'Salary(USD)')
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 28638                          I am a developer by profession      True
# 722                            I am a developer by profession     False
# 13825                          I am a developer by profession      True
# 40913                          I am a developer by profession      True
# 30630                          I am a developer by profession      True
# 69049                          I am a developer by profession     False
# 19340       I am not primarily a developer, but I write co...      True
# 16214       I am not primarily a developer, but I write co...      True
# 29355                          I am a developer by profession      True
# 1685                           I am a developer by profession      True
#
#                                                   OpenSourcer  \
# Respondent
# 28638       Less than once a month but more than once per ...
# ...

# %%
df['Salary(USD)'].head(15)
# Out:
# Respondent
# 63129    1000000.0
# 50499     153216.0
# 39258      19152.0
# 58450      17556.0
# 7085       14364.0
# 22450       7980.0
# 48436       4464.0
# 10746       3996.0
# 8149        1596.0
# 29736       1116.0
# 28638          0.0
# 722            0.0
# 85715          NaN
# 50767          NaN
# 2782           NaN
# Name: Salary(USD), dtype: float64

# %%
df.sort_values(by = ['Respondent'],inplace=True)

# %%
df
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      True
# 2                      I am a student who is learning to code     False
# 3           I am not primarily a developer, but I write co...      True
# 4                              I am a developer by profession     False
# 5                              I am a developer by profession      True
# ...                                                       ...       ...
# 88879                          I am a developer by profession      True
# 88880       I am not primarily a developer, but I write co...      True
# 88881                          I am a developer by profession      True
# 88882                          I am a developer by profession      True
# 88883                          I am a developer by profession      True
#
#                            OpenSourcer  \
# Respondent
# ...

# %%
df['Salary(USD)'].head(15)
# Out:
# Respondent
# 1          NaN
# 2          NaN
# 3       8820.0
# 4      61000.0
# 5          NaN
# 6     366420.0
# 7          NaN
# 8          NaN
# 9      95179.0
# 10     13293.0
# 11         NaN
# 12         NaN
# 13     90000.0
# 14     57060.0
# 15         NaN
# Name: Salary(USD), dtype: float64

# %% [markdown]
# ### Calculating the median salary

# %%
df['Salary(USD)'].median()
# Out:
# 57287.0

# %% [markdown]
# ### Calculates the median of all the numeric columns present in the dataframe

# %%
df.median()
# Out:
# /var/folders/94/1pncpdl52rd2f4y897xjvsq40000gn/T/ipykernel_85242/530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# Hobbyist           1.0
# CompTotal      62000.0
# Salary(USD)    57287.0
# WorkWeekHrs       40.0
# CodeRevHrs         4.0
# Age               29.0
# dtype: float64

# %% [markdown]
# ### Gives a lot of numeric data about the dataframe

# %%
df.describe()
# Out:
#           CompTotal   Salary(USD)   WorkWeekHrs    CodeRevHrs           Age
# count  5.594500e+04  5.582300e+04  64503.000000  49790.000000  79210.000000
# mean   5.519014e+11  1.271107e+05     42.127197      5.084308     30.336699
# std    7.331926e+13  2.841523e+05     37.287610      5.513931      9.178390
# min    0.000000e+00  0.000000e+00      1.000000      0.000000      1.000000
# 25%    2.000000e+04  2.577750e+04     40.000000      2.000000     24.000000
# 50%    6.200000e+04  5.728700e+04     40.000000      4.000000     29.000000
# 75%    1.200000e+05  1.000000e+05     44.750000      6.000000     35.000000
# max    1.000000e+16  2.000000e+06   4850.000000     99.000000     99.000000

# %% [markdown]
# ### count function returns the no of respondent who have filled that particular column

# %%
df['Salary(USD)'].count()
# Out:
# 55823

# %%
df['Hobbyist']
# Out:
# Respondent
# 1         True
# 2        False
# 3         True
# 4        False
# 5         True
#          ...
# 88879     True
# 88880     True
# 88881     True
# 88882     True
# 88883     True
# Name: Hobbyist, Length: 88883, dtype: bool

# %% [markdown]
# ### This function the counting of each particular value in a column

# %%
df['Hobbyist'].value_counts()
# Out:
# True     71257
# False    17626
# Name: Hobbyist, dtype: int64

# %%
df['SocialMedia']
# Out:
# Respondent
# 1          Twitter
# 2        Instagram
# 3           Reddit
# 4           Reddit
# 5         Facebook
#            ...
# 88879      YouTube
# 88880          NaN
# 88881          NaN
# 88882    Instagram
# 88883       Reddit
# Name: SocialMedia, Length: 88883, dtype: object

# %%
schema_df.loc['SocialMedia']
# Out:
# QuestionText    What social media site do you use the most?
# Name: SocialMedia, dtype: object

# %%
df['SocialMedia'].value_counts()
# Out:
# Reddit                      14374
# YouTube                     13830
# WhatsApp                    13347
# Facebook                    13178
# Twitter                     11398
# Instagram                    6261
# I don't use social media     5554
# LinkedIn                     4501
# WeChat 微信                     667
# Snapchat                      628
# VK ВКонта́кте                 603
# Weibo 新浪微博                     56
# Youku Tudou 优酷                 21
# Hello                          19
# Name: SocialMedia, dtype: int64

# %% [markdown]
# ### This gives us the percentage of each value in a column

# %%
df['SocialMedia'].value_counts(normalize=True)
# Out:
# Reddit                      0.170233
# YouTube                     0.163791
# WhatsApp                    0.158071
# Facebook                    0.156069
# Twitter                     0.134988
# Instagram                   0.074150
# I don't use social media    0.065777
# LinkedIn                    0.053306
# WeChat 微信                   0.007899
# Snapchat                    0.007437
# VK ВКонта́кте               0.007141
# Weibo 新浪微博                  0.000663
# Youku Tudou 优酷              0.000249
# Hello                       0.000225
# Name: SocialMedia, dtype: float64

# %%
df['Country'].value_counts()
# Out:
# United States        20949
# India                 9061
# Germany               5866
# United Kingdom        5737
# Canada                3395
#                      ...
# Tonga                    1
# Timor-Leste              1
# North Korea              1
# Brunei Darussalam        1
# Chad                     1
# Name: Country, Length: 179, dtype: int64

# %% [markdown]
# ### Forming a group of different countries

# %%
 df.groupby(['Country'])

# %% [markdown]
# ### Storing the group in a variable

# %%
country_grp = df.groupby(['Country'])

# %% [markdown]
# ### Displaying a specific country from the group of countries

# %%
country_grp.get_group('United States')
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 4                              I am a developer by profession     False
# 13                             I am a developer by profession      True
# 22                             I am a developer by profession      True
# 23                             I am a developer by profession      True
# 26                             I am a developer by profession      True
# ...                                                       ...       ...
# 88875       I used to be a developer by profession, but no...      True
# 88876                          I am a developer by profession      True
# 88877                          I am a developer by profession      True
# 88878                          I am a developer by profession      True
# 88880       I am not primarily a developer, but I write co...      True
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
country_grp.get_group('India')
# Out:
#                                         MainBranch  Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      True
# 10                  I am a developer by profession      True
# 15          I am a student who is learning to code      True
# 50                  I am a developer by profession      True
# 65                  I am a developer by profession      True
# ...                                            ...       ...
# 88829       I am a student who is learning to code      True
# 88843               I am a developer by profession      True
# 88856               I am a developer by profession      True
# 88869               I am a developer by profession     False
# 88872               I am a developer by profession      True
#
#                                                   OpenSourcer  \
# Respondent
# 8                                     Less than once per year
# 10                                 Once a month or more often
# ...

# %%
filt = df['Country'] == 'United States'
df.loc[filt]
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 4                              I am a developer by profession     False
# 13                             I am a developer by profession      True
# 22                             I am a developer by profession      True
# 23                             I am a developer by profession      True
# 26                             I am a developer by profession      True
# ...                                                       ...       ...
# 88875       I used to be a developer by profession, but no...      True
# 88876                          I am a developer by profession      True
# 88877                          I am a developer by profession      True
# 88878                          I am a developer by profession      True
# 88880       I am not primarily a developer, but I write co...      True
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %% [markdown]
# ### Using filter to form group

# %%
filt = df['Country'] == 'United States'
df.loc[filt]['SocialMedia'].value_counts()
# Out:
# Reddit                      5700
# Twitter                     3468
# Facebook                    2844
# YouTube                     2463
# I don't use social media    1851
# Instagram                   1652
# LinkedIn                    1020
# WhatsApp                     609
# Snapchat                     326
# WeChat 微信                     93
# VK ВКонта́кте                  9
# Weibo 新浪微博                     8
# Hello                          2
# Youku Tudou 优酷                 1
# Name: SocialMedia, dtype: int64

# %%
filt = df['Country'] == 'India'
df.loc[filt]['SocialMedia'].value_counts()
# Out:
# WhatsApp                    2990
# YouTube                     1820
# LinkedIn                     955
# Facebook                     841
# Instagram                    822
# Twitter                      542
# Reddit                       473
# I don't use social media     250
# Snapchat                      23
# Hello                          5
# WeChat 微信                      5
# VK ВКонта́кте                  4
# Youku Tudou 优酷                 2
# Weibo 新浪微博                     1
# Name: SocialMedia, dtype: int64

# %% [markdown]
# ### Printing the country wise usage of diff social media platforms

# %%
country_grp['SocialMedia'].value_counts()
# Out:
# Country      SocialMedia
# Afghanistan  Facebook                    15
#              YouTube                      9
#              I don't use social media     6
#              WhatsApp                     4
#              Instagram                    1
#                                          ..
# Zimbabwe     Facebook                     3
#              YouTube                      3
#              Instagram                    2
#              LinkedIn                     2
#              Reddit                       1
# Name: SocialMedia, Length: 1220, dtype: int64

# %% [markdown]
# ### Social media usage of a particular country

# %%
country_grp['SocialMedia'].value_counts().loc['India']
# Out:
# SocialMedia
# WhatsApp                    2990
# YouTube                     1820
# LinkedIn                     955
# Facebook                     841
# Instagram                    822
# Twitter                      542
# Reddit                       473
# I don't use social media     250
# Snapchat                      23
# Hello                          5
# WeChat 微信                      5
# VK ВКонта́кте                  4
# Youku Tudou 优酷                 2
# Weibo 新浪微博                     1
# Name: SocialMedia, dtype: int64

# %%
country_grp['SocialMedia'].value_counts().loc['United States']
# Out:
# SocialMedia
# Reddit                      5700
# Twitter                     3468
# Facebook                    2844
# YouTube                     2463
# I don't use social media    1851
# Instagram                   1652
# LinkedIn                    1020
# WhatsApp                     609
# Snapchat                     326
# WeChat 微信                     93
# VK ВКонта́кте                  9
# Weibo 新浪微博                     8
# Hello                          2
# Youku Tudou 优酷                 1
# Name: SocialMedia, dtype: int64

# %%
country_grp['SocialMedia'].value_counts(normalize=True).loc['United States']
# Out:
# SocialMedia
# Reddit                      0.284346
# Twitter                     0.173002
# Facebook                    0.141874
# YouTube                     0.122867
# I don't use social media    0.092338
# Instagram                   0.082410
# LinkedIn                    0.050883
# WhatsApp                    0.030380
# Snapchat                    0.016263
# WeChat 微信                   0.004639
# VK ВКонта́кте               0.000449
# Weibo 新浪微博                  0.000399
# Hello                       0.000100
# Youku Tudou 优酷              0.000050
# Name: SocialMedia, dtype: float64

# %% [markdown]
# ### Getting the median salary in each country using grouping

# %%
country_grp['Salary(USD)'].median()
# Out:
# Country
# Afghanistan                               6222.0
# Albania                                  10818.0
# Algeria                                   7878.0
# Andorra                                 160931.0
# Angola                                    7764.0
#                                           ...
# Venezuela, Bolivarian Republic of...      6384.0
# Viet Nam                                 11892.0
# Yemen                                    11940.0
# Zambia                                    5040.0
# Zimbabwe                                 19200.0
# Name: Salary(USD), Length: 179, dtype: float64

# %%
country_grp['Salary(USD)'].median().loc['India']
# Out:
# 10080.0

# %% [markdown]
# ### Median and mean together for each country

# %%
country_grp['Salary(USD)'].agg(['median' , 'mean'])
# Out:
#                                         median           mean
# Country
# Afghanistan                             6222.0  101953.333333
# Albania                                10818.0   21833.700000
# Algeria                                 7878.0   34924.047619
# Andorra                               160931.0  160931.000000
# Angola                                  7764.0    7764.000000
# ...                                        ...            ...
# Venezuela, Bolivarian Republic of...    6384.0   14581.627907
# Viet Nam                               11892.0   17233.436782
# Yemen                                  11940.0   16909.166667
# Zambia                                  5040.0   10075.375000
# Zimbabwe                               19200.0   34046.666667
#
# [179 rows x 2 columns]

# %%
country_grp['Salary(USD)'].agg(['median' , 'mean']).loc['India']
# Out:
# median    10080.000000
# mean      28057.664916
# Name: India, dtype: float64

# %% [markdown]
# ### To get the people who are from India and their languages

# %%
filt = df['Country'] == 'India'
df.loc[filt]['LanguageWorkedWith']
# Out:
# Respondent
# 8        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 10                           C#;Go;JavaScript;Python;R;SQL
# 15       Assembly;Bash/Shell/PowerShell;C;C++;HTML/CSS;...
# 50       Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 65                         Assembly;C;C++;C#;HTML/CSS;Java
#                                ...
# 88829    Bash/Shell/PowerShell;C;C++;HTML/CSS;JavaScrip...
# 88843    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 88856                   HTML/CSS;JavaScript;PHP;TypeScript
# 88869                          HTML/CSS;JavaScript;PHP;SQL
# 88872                                        Java;Ruby;SQL
# Name: LanguageWorkedWith, Length: 9061, dtype: object

# %% [markdown]
# ### To check people who uses python as a language

# %%
filt = df['Country'] == 'India'
df.loc[filt]['LanguageWorkedWith'].str.contains('Python')
# Out:
# Respondent
# 8         True
# 10        True
# 15       False
# 50        True
# 65       False
#          ...
# 88829     True
# 88843     True
# 88856    False
# 88869    False
# 88872    False
# Name: LanguageWorkedWith, Length: 9061, dtype: object

# %%
filt = df['Country'] == 'India'
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').value_counts()
# Out:
# False    5739
# True     3105
# Name: LanguageWorkedWith, dtype: int64

# %%
filt = df['Country'] == 'India'
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 3105

# %% [markdown]
# ### No of people who uses python from each country

# %%
country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
country_respondents = df['Country'].value_counts()

# %%
country_respondents
# Out:
# United States        20949
# India                 9061
# Germany               5866
# United Kingdom        5737
# Canada                3395
#                      ...
# Tonga                    1
# Timor-Leste              1
# North Korea              1
# Brunei Darussalam        1
# Chad                     1
# Name: Country, Length: 179, dtype: int64

# %%
country_python = country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())

# %%
country_python
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %% [markdown]
# ### Concating two columns , one for no of respondents and one for the no of python users

# %%
python_df =  pd.concat([country_respondents,country_python], axis = 'columns',sort= False)

# %%
python_df
# Out:
#                    Country  LanguageWorkedWith
# United States        20949               10083
# India                 9061                3105
# Germany               5866                2451
# United Kingdom        5737                2384
# Canada                3395                1558
# ...                    ...                 ...
# Tonga                    1                   0
# Timor-Leste              1                   1
# North Korea              1                   0
# Brunei Darussalam        1                   0
# Chad                     1                   0
#
# [179 rows x 2 columns]

# %%
python_df .rename(columns ={ 'Country' : 'NumberOfRespond', 'LanguageWorkedWith' : 'Python'},inplace=True)

# %%
python_df
# Out:
#                    NumberOfRespond  Python
# United States                20949   10083
# India                         9061    3105
# Germany                       5866    2451
# United Kingdom                5737    2384
# Canada                        3395    1558
# ...                            ...     ...
# Tonga                            1       0
# Timor-Leste                      1       1
# North Korea                      1       0
# Brunei Darussalam                1       0
# Chad                             1       0
#
# [179 rows x 2 columns]

# %% [markdown]
# ### Calculating the percentage of pyhton users in a specific country

# %%
python_df['PercentKnowPython'] = (python_df['Python']/python_df['NumberOfRespond'])*100

# %%
python_df
# Out:
#                    NumberOfRespond  Python  PercentKnowPython
# United States                20949   10083          48.131176
# India                         9061    3105          34.267741
# Germany                       5866    2451          41.783157
# United Kingdom                5737    2384          41.554820
# Canada                        3395    1558          45.891016
# ...                            ...     ...                ...
# Tonga                            1       0           0.000000
# Timor-Leste                      1       1         100.000000
# North Korea                      1       0           0.000000
# Brunei Darussalam                1       0           0.000000
# Chad                             1       0           0.000000
#
# [179 rows x 3 columns]

# %%
python_df.sort_values(by = 'PercentKnowPython', ascending = False)
# Out:
#                        NumberOfRespond  Python  PercentKnowPython
# Sao Tome and Principe                1       1         100.000000
# Niger                                1       1         100.000000
# Timor-Leste                          1       1         100.000000
# Dominica                             1       1         100.000000
# Turkmenistan                         7       6          85.714286
# ...                                ...     ...                ...
# Cape Verde                           3       0           0.000000
# Malawi                               2       0           0.000000
# Liberia                              2       0           0.000000
# Gabon                                2       0           0.000000
# Chad                                 1       0           0.000000
#
# [179 rows x 3 columns]

# %%
python_df.sort_values(by = 'PercentKnowPython', ascending = False,inplace = True)

# %%
python_df.head(50)
# Out:
#                                   NumberOfRespond  Python  PercentKnowPython
# Sao Tome and Principe                           1       1         100.000000
# Niger                                           1       1         100.000000
# Timor-Leste                                     1       1         100.000000
# Dominica                                        1       1         100.000000
# Turkmenistan                                    7       6          85.714286
# Mauritania                                      7       5          71.428571
# Bahamas                                         3       2          66.666667
# Guinea                                          3       2          66.666667
# Guyana                                          3       2          66.666667
# Uganda                                         72      47          65.277778
# Iceland                                        49      30          61.224490
# ...

# %%
python_df.loc['India']
# Out:
# NumberOfRespond      9061.000000
# Python               3105.000000
# PercentKnowPython      34.267741
# Name: India, dtype: float64

# %%
df['YearsCode'].head(10)
# Out:
# Respondent
# 1       4
# 2     NaN
# 3       3
# 4       3
# 5      16
# 6      13
# 7       6
# 8       8
# 9      12
# 10     12
# Name: YearsCode, dtype: object

# %%
df['YearsCode'].unique()
# Out:
# array(['4', nan, '3', '16', '13', '6', '8', '12', '2', '5', '17', '10',
#        '14', '35', '7', 'Less than 1 year', '30', '9', '26', '40', '19',
#        '15', '20', '28', '25', '1', '22', '11', '33', '50', '41', '18',
#        '34', '24', '23', '42', '27', '21', '36', '32', '39', '38', '31',
#        '37', 'More than 50 years', '29', '44', '45', '48', '46', '43',
#        '47', '49'], dtype=object)

# %%
df['YearsCode'].replace('Less than 1 year', 0 , inplace = True)

# %%
df['YearsCode'].replace('More than 50 years', 51 , inplace = True)

# %%
df['YearsCode'].unique()
# Out:
# array(['4', nan, '3', '16', '13', '6', '8', '12', '2', '5', '17', '10',
#        '14', '35', '7', 0, '30', '9', '26', '40', '19', '15', '20', '28',
#        '25', '1', '22', '11', '33', '50', '41', '18', '34', '24', '23',
#        '42', '27', '21', '36', '32', '39', '38', '31', '37', 51, '29',
#        '44', '45', '48', '46', '43', '47', '49'], dtype=object)

# %%
df['YearsCode']= df['YearsCode'].astype(float)

# %%
df['YearsCode'].mean()
# Out:
# 11.662114216834588

# %%
df['YearsCode'].median()
# Out:
# 9.0
